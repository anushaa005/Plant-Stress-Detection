# %%
pip install "ultralytics<=8.3.40"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.5/898.5 kB 27.2 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !yolo task=detect
mode=train
model=yolov8s.pt
data="/content/drive/MyDrive/plantDisease/data.yaml"
epochs=100
imgsz=640
# Out:
# WARNING ⚠️ 'mode' argument is missing. Valid modes are {'export', 'val', 'benchmark', 'predict', 'track', 'train'}. Using default 'mode=train'.
# WARNING ⚠️ 'data' argument is missing. Using default 'data=coco8.yaml'.
# New https://pypi.org/project/ultralytics/8.4.14 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.12.12 torch-2.9.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
import shutil

source = "/content/runs/detect/train"
destination = "/content/drive/MyDrive/PlantDoc/training_results"

shutil.copytree(source, destination, dirs_exist_ok=True)

print("Results saved to Google Drive successfully!")
# Out:
# Results saved to Google Drive successfully!

# %%
# !yolo task=detect mode=train
model="/content/drive/MyDrive/PlantDoc/training_results/weights/best.pt"
data="/content/drive/MyDrive/plantDisease/data.yaml"
epochs=150
imgsz=640
lr0=0.001
patience=30
# Out:
# WARNING ⚠️ 'data' argument is missing. Using default 'data=coco8.yaml'.
# New https://pypi.org/project/ultralytics/8.4.14 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.12.12 torch-2.9.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
import shutil

source = "/content/runs/detect/train"
destination = "/content/drive/MyDrive/PlantFinal/training_results"

shutil.copytree(source, destination, dirs_exist_ok=True)

print("Results saved to Google Drive successfully!")
# Out:
# Results saved to Google Drive successfully!

# %%
# !yolo task=detect
mode=train
model=yolov8s.pt
data="/content/drive/MyDrive/PlantFinal/data.yaml"
epochs=100
imgsz=640
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# WARNING ⚠️ 'mode' argument is missing. Valid modes are {'benchmark', 'predict', 'export', 'val', 'track', 'train'}. Using default 'mode=train'.
# ...
# 100% 5.35M/5.35M [00:00<00:00, 107MB/s]
# WARNING ⚠️ 'data' argument is missing. Using default 'data=coco8.yaml'.
# New https://pypi.org/project/ultralytics/8.4.14 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.12.12 torch-2.9.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
